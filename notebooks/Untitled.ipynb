# %% [markdown]
# ```bash
# kedro jupyter notebook
# ```

# %%
pipelines
# Out:
# {'__default__': Pipeline([
# Node(create_torch_dataset, ['raw_images', 'target_masks'], 'dataset', None)
# ]), 'model_train': Pipeline([]), 'data_loader': Pipeline([
# Node(create_torch_dataset, ['raw_images', 'target_masks'], 'dataset', None)
# ]), 'model_create': Pipeline([])}

# %%
dataset = catalog.load("dataset")
# Out:
# [05/24/23 14:37:17] INFO     Loading data from 'dataset' (PickleDataSet)...                     ]8;id=512443;file:///home/pslowiq/programs/pdl2023/dl-skin-lesion-recognition/env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=433655;file:///home/pslowiq/programs/pdl2023/dl-skin-lesion-recognition/env/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
from PIL import Image

# %%
dataset[0][0].shape
dataset[0][0].numpy().shape
# Out:
# (3, 914, 1225)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(30,12))

take_n_every = 10

for j in range(5):
        axes[0][j].imshow(np.transpose(dataset[j*take_n_every][0], (1, 2, 0)))
        axes[0][j].set_title('Image\n' + dataset.get_image_name(j*take_n_every))
        axes[1][j].imshow(np.transpose(dataset[j*take_n_every][1], (1, 2, 0)))
        axes[1][j].set_title('Target mask\n' + dataset.get_target_name(j*take_n_every))
